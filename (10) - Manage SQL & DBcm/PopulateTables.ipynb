# %%
fn = 'Abi-10-100m-Back.txt'
name, age, distance, stroke = fn.removesuffix(".txt").split("-")

# %%
name, age
# Out:
# ('Abi', '10')

# %%
distance, stroke
# Out:
# ('100m', 'Back')

# %%
import os

FOLDER = "swimdata/"

files = os.listdir(FOLDER)
files.remove(".DS_Store")

# %%
first = files[0]
print(first)
name, age, _, _ = first.removesuffix(".txt").split("-")
name, age
# Out:
# Hannah-13-100m-Free.txt
# ('Hannah', '13')

# %%
# Don't be tempted to do this (i.e., don't use an f-string here).

SQL = f"""
    insert into swimmers
    (name, age)
    values
    ("{name}", {age})
"""
print(SQL)
# Out:
#     insert into swimmers
#     (name, age)
#     values
#     ("Hannah", 13)

# %%
import DBcm

db_details = "CoachDB.sqlite3"

# %%
# Do this instead... use SQL Injection Attack safeguards with placeholders.

SQL_INSERT = """
    insert into swimmers
    (name, age)
    values
    (?, ?)
"""
print(SQL_INSERT)
# Out:
#     insert into swimmers
#     (name, age)
#     values
#     (?, ?)

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL_INSERT, (name, age,))

# %%
SQL = """select * from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(2580, 'Hannah', 13),
#  (2581, 'Darius', 13),
#  (2582, 'Owen', 15),
#  (2583, 'Mike', 15),
#  (2584, 'Ruth', 13),
#  (2585, 'Tasmin', 15),
#  (2586, 'Erika', 15),
#  (2587, 'Abi', 10),
#  (2588, 'Maria', 9),
#  (2589, 'Elba', 14),
#  (2590, 'Ali', 12),
#  (2591, 'Chris', 17),
#  (2592, 'Aurora', 13),
#  (2593, 'Katie', 9),
#  (2594, 'Alison', 14),
#  (2595, 'Emma', 13),
#  (2596, 'Calvin', 9),
#  (2597, 'Blake', 15),
#  (2598, 'Bill', 18),
#  (2599, 'Dave', 17),
#  (2600, 'Lizzie', 14),
#  (2601, 'Carl', 15),
#  (2602, 'Hannah', 13)]

# %%
SQL = """delete from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
SQL = """select * from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# []

# %%
SQL = """delete from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
# for fn in files:
#     name, age, _, _ = fn.removesuffix(".txt").split("-")
#     with DBcm.UseDatabase(db_details) as db:
#         db.execute(SQL_INSERT, (name, age, ))

# %%
import os

import DBcm

db_details = "CoachDB.sqlite3"

FOLDER = "swimdata/"

files = os.listdir(FOLDER)
files.remove(".DS_Store")

SQL_INSERT = """
    insert into swimmers
    (name, age)
    values
    (?, ?)
"""

with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        name, age, _, _ = fn.removesuffix(".txt").split("-")    
        db.execute(SQL_INSERT, (name, age, ))

# %%
SQL = """delete from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
import os

import DBcm

db_details = "CoachDB.sqlite3"

FOLDER = "swimdata/"

files = os.listdir(FOLDER)
files.remove(".DS_Store")

SQL_SELECT = """
    select * from swimmers
    where name = ? and age = ?
"""

SQL_INSERT = """
    insert into swimmers
    (name, age)
    values
    (?, ?)
"""

with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        name, age, _, _ = fn.removesuffix(".txt").split("-")
        db.execute(SQL_SELECT, (name, age,))
        if db.fetchall():
            continue
        db.execute(SQL_INSERT, (name, age,))

# %%
import os

import DBcm

db_details = "CoachDB.sqlite3"

FOLDER = "swimdata/"

files = os.listdir(FOLDER)
files.remove(".DS_Store")

SQL_SELECT = """
    select * from events
    where distance = ? and stroke = ?
"""

SQL_INSERT = """
    insert into events
    (distance, stroke)
    values
    (?, ?)
"""

with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        _, _, distance, stroke = fn.removesuffix(".txt").split("-")
        db.execute(SQL_SELECT, (distance, stroke,))
        if db.fetchall():
            continue
        db.execute(SQL_INSERT, (distance, stroke,))

# %%
import os

FOLDER = "swimdata/"

files = os.listdir(FOLDER)
files.remove(".DS_Store")

# %%
import DBcm

db_details = "CoachDB.sqlite3"

# %%
SQL = """select * from swimmers"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(2661, 'Hannah', 13),
#  (2662, 'Darius', 13),
#  (2663, 'Owen', 15),
#  (2664, 'Mike', 15),
#  (2665, 'Ruth', 13),
#  (2666, 'Tasmin', 15),
#  (2667, 'Erika', 15),
#  (2668, 'Abi', 10),
#  (2669, 'Maria', 9),
#  (2670, 'Elba', 14),
#  (2671, 'Ali', 12),
#  (2672, 'Chris', 17),
#  (2673, 'Aurora', 13),
#  (2674, 'Katie', 9),
#  (2675, 'Alison', 14),
#  (2676, 'Emma', 13),
#  (2677, 'Calvin', 9),
#  (2678, 'Blake', 15),
#  (2679, 'Bill', 18),
#  (2680, 'Dave', 17),
#  (2681, 'Lizzie', 14),
#  (2682, 'Carl', 15)]

# %%
SQL = """select * from events"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(1, '100m', 'Free'),
#  (2, '100m', 'Back'),
#  (3, '100m', 'Fly'),
#  (4, '200m', 'Free'),
#  (5, '200m', 'Back'),
#  (6, '50m', 'Free'),
#  (7, '50m', 'Breast'),
#  (8, '200m', 'IM'),
#  (9, '100m', 'Breast'),
#  (10, '400m', 'Free'),
#  (11, '50m', 'Fly'),
#  (12, '50m', 'Back'),
#  (13, '200m', 'Breast')]

# %%
with DBcm.UseDatabase(db_details) as db:
    db.execute("pragma table_info(times)")
    results = db.fetchall()
results
# Out:
# [(0, 'swimmer_id', 'INTEGER', 1, None, 0),
#  (1, 'event_id', 'INTEGER', 1, None, 0),
#  (2, 'time', 'varchar(16)', 1, None, 0),
#  (3, 'ts', 'timestamp', 1, 'current_timestamp', 0)]

# %%
# the above code checks the rows of the table 'times' define earlier in the code.

# %%
SQL_GET_SWIMMER = """
    select id from swimmers
    where name = ? and age = ?
"""

# %%
SQL_GET_EVENT = """
    select id from events
    where distance = ? and stroke = ?
"""

# %%
SQL_INSERT = """
    insert into times
    (swimmer_id, event_id, time)
    values
    (?, ?, ?)
"""

# %%
SQL = """select * from times"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL
#  (2598, 2, '1:05.82', '2025-01-26 06:18:09'),
#  (2593, 1, '1:20.81', '2025-01-26 06:18:09'),
#  (2593, 1, '1:23.61', '2025-01-26 06:18:09'),
#  (2593, 1, '1:24.80', '2025-01-26 06:18:09'),
#  (2593, 1, '1:22.05', '2025-01-26 06:18:09'),
#  (2593, 1, '1:22.58', '2025-01-26 06:18:09'),
#  (2593, 1, '1:23.94', '2025-01-26 06:18:09'),
#  (2597, 3, '1:11.49', '2025-01-26 06:18:09'),
#  (2597, 3, '1:10.16', '2025-01-26 06:18:09'),
#  (2597, 3, '1:12.59', '2025-01-26 06:18:09'),
#  (2597, 3, '1:11.63', '2025-01-26 06:18:09'),
#  (2597, 3, '1:09.43', '2025-01-26 06:18:09'),
#  (2586, 9, '1:36.72', '2025-01-26 06:18:09'),
#  (2586, 9, '1:34.78', '2025-01-26 06:18:09'),
#  (2586, 9, '1:34.05', '2025-01-26 06:18:09'),
#  (2586, 9, '1:32.78', '2025-01-26 06:18:09'),
#  (2586, 9, '1:33.51', '2025-01-26 06:18:09'),
#  (2586, 9, '1:33.29', '2025-01-26 06:18:09'),
#  (2586, 9, '1:36.47', '2025-01-26 06:18:09'),
#  (2586, 9, '1:31.82', '2025-01-26 06:18:09'),
#  (2593, 2, '1:33.36', '2025-01-26 06:18:09'),
#  (2593, 2, '1:31.52', '2025-01-26 06:18:09'),
#  (2593, 2, '1:28.10', '2025-01-26 06:18:09'),
#  (2593, 2, '1:33.37', '2025-01-26 06:18:09'),
#  (2593, 2, '1:32.89', '2025-01-26 06:18:09'),
#  (2593, 2, '1:33.38', '2025-01-26 06:18:09'),
#  (2593, 2, '1:32.03', '2025-01-26 06:18:09'),
#  (2593, 2, '1:32.71', '2025-01-26 06:18:09')]

# %%
SQL = """delete from times"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)

# %%
with DBcm.UseDatabase(db_details) as db:
    for fn in files:
        name, age, distance, stroke = fn.removesuffix(".txt").split("-")
        db.execute(SQL_GET_SWIMMER, (name, age,))
        s_id = db.fetchone()[0]
        db.execute(SQL_GET_EVENT, (distance, stroke,))
        e_id = db.fetchone()[0]
        with open(FOLDER+fn) as sf:
            times = sf.read().strip().split(",")
            for t in times:
                db.execute(SQL_INSERT, (s_id, e_id, t,))

# %%
SQL = """select count(*) from times"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchone()[0]
results
# Out:
# 322

# %%
SQL = """select * from times limit 10"""
with DBcm.UseDatabase(db_details) as db:
    db.execute(SQL)
    results = db.fetchall()
results
# Out:
# [(2661, 1, '1:21.43', '2025-01-26 06:18:11'),
#  (2661, 1, '1:21.40', '2025-01-26 06:18:11'),
#  (2661, 1, '1:21.62', '2025-01-26 06:18:11'),
#  (2661, 1, '1:25.38', '2025-01-26 06:18:11'),
#  (2662, 2, '1:22.57', '2025-01-26 06:18:11'),
#  (2662, 2, '1:29.64', '2025-01-26 06:18:11'),
#  (2662, 2, '1:20.39', '2025-01-26 06:18:11'),
#  (2662, 2, '1:23.83', '2025-01-26 06:18:11'),
#  (2663, 1, '1:15.57', '2025-01-26 06:18:11'),
#  (2663, 1, '1:14.40', '2025-01-26 06:18:11')]

# %%
# %pip install pandas lxml --upgrade
# Out:
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (2.2.3)
# Requirement already satisfied: lxml in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (5.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from pandas) (2025.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (24.3.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
# lxml is a dependency of pandas, and it is used to parse HTML tables, meaning it is an analytical software.

# %%
import pandas as pd

# %%
URL = "https://en.wikipedia.org/wiki/List_of_world_records_in_swimming"

# %%
tables = pd.read_html(URL) # In this case, 'tables' is no longer a soup object, but a list of dataframes/spreadsheet.

# %%
# The .read_html() function automatically finds, parses, and extracts the <table> tags from the identified web page, turning each table into a dataframe.

# %%
tables[0]
# Out:
#                         Event      Time Unnamed: 2  \
# 0               50m freestyle     20.91         ss
# 1              100m freestyle     46.40        NaN
# 2              200m freestyle   1:42.00         ss
# 3              400m freestyle   3:40.07         ss
# 4              800m freestyle   7:32.12         ss
# 5             1500m freestyle  14:30.67        NaN
# 6              50m backstroke     23.55         sf
# 7             100m backstroke     51.60        NaN
# 8             200m backstroke   1:51.92         ss
# 9            50m breaststroke     25.95         sf
# 10          100m breaststroke     56.88         sf
# 11          200m breaststroke   2:05.48        NaN
# 12              50m butterfly     22.27        NaN
# 13             100m butterfly     49.45        NaN
# 14             200m butterfly   1:50.34        NaN
# 15     200m individual medley   1:54.00        NaN
# 16     400m individual medley   4:02.50        NaN
# 17  4 × 100 m freestyle relay   3:08.24         ss
# 18  4 × 200 m freestyle relay   6:58.55         ss
# 19     4 × 100 m medley relay   3:26.78        NaN
#
#                                                  Name    Nationality  \
# 0                                         César Cielo         Brazil
# 1                                          Pan Zhanle          China
# 2                                     Paul Biedermann        Germany
# 3                                     Paul Biedermann        Germany
# 4                                           Zhang Lin          China
# 5                                         Bobby Finke  United States
# 6                                  Kliment Kolesnikov         Russia
# 7                                       Thomas Ceccon          Italy
# 8                                       Aaron Peirsol  United States
# 9                                          Adam Peaty  Great Britain
# 10                                         Adam Peaty  Great Britain
# 11                                        Qin Haiyang          China
# 12                                     Andriy Govorov        Ukraine
# 13                                     Caeleb Dressel  United States
# 14                                      Kristóf Milák        Hungary
# 15                                        Ryan Lochte  United States
# 16                                      Léon Marchand         France
# 17  Michael Phelps (47.51)Garrett Weber-Gale (47.0...  United States
# 18  Michael Phelps (1:44.49)Ricky Berens (1:44.13)...  United States
# 19  Ryan Murphy (52.31)Michael Andrew (58.49)Caele...  United States
#
#                 Date                     Meet              Location  \
# 0   18 December 2009  Brazilian Championships     São Paulo, Brazil
# 1       31 July 2024            Olympic Games         Paris, France
# 2       28 July 2009      World Championships           Rome, Italy
# 3       26 July 2009      World Championships           Rome, Italy
# 4       29 July 2009      World Championships           Rome, Italy
# 5      4 August 2024            Olympic Games         Paris, France
# 6       27 July 2023              Russian Cup         Kazan, Russia
# 7       20 June 2022      World Championships     Budapest, Hungary
# 8       31 July 2009      World Championships           Rome, Italy
# 9       25 July 2017      World Championships     Budapest, Hungary
# 10      21 July 2019      World Championships  Gwangju, South Korea
# 11      28 July 2023      World Championships        Fukuoka, Japan
# 12       1 July 2018       Sette Colli Trophy           Rome, Italy
# 13      31 July 2021            Olympic Games          Tokyo, Japan
# 14      21 June 2022      World Championships     Budapest, Hungary
# 15      28 July 2011      World Championships       Shanghai, China
# 16      23 July 2023      World Championships        Fukuoka, Japan
# 17    11 August 2008            Olympic Games        Beijing, China
# 18      31 July 2009      World Championships           Rome, Italy
# 19     1 August 2021            Olympic Games          Tokyo, Japan
#
#                 Ref
# 0   [9][10][11][12]
# 1              [13]
# 2      [14][15][16]
# 3      [17][18][19]
# 4          [20][21]
# 5         [22] [23]
# 6              [24]
# 7          [26][27]
# 8      [28][29][30]
# 9          [31][32]
# 10         [33][34]
# 11        [35] [36]
# 12         [37][38]
# 13         [39][40]
# 14         [41][42]
# 15     [43][44][45]
# 16        [46] [47]
# 17     [48][49][50]
# 18         [51][52]
# 19        [53] [54]

# %%
tables[0].head() # The .head() function is used to display the first 5 rows of the dataframe, by default.
# Out:
#             Event     Time Unnamed: 2             Name Nationality  \
# 0   50m freestyle    20.91         ss      César Cielo      Brazil
# 1  100m freestyle    46.40        NaN       Pan Zhanle       China
# 2  200m freestyle  1:42.00         ss  Paul Biedermann     Germany
# 3  400m freestyle  3:40.07         ss  Paul Biedermann     Germany
# 4  800m freestyle  7:32.12         ss        Zhang Lin       China
#
#                Date                     Meet           Location  \
# 0  18 December 2009  Brazilian Championships  São Paulo, Brazil
# 1      31 July 2024            Olympic Games      Paris, France
# 2      28 July 2009      World Championships        Rome, Italy
# 3      26 July 2009      World Championships        Rome, Italy
# 4      29 July 2009      World Championships        Rome, Italy
#
#                Ref
# 0  [9][10][11][12]
# 1             [13]
# 2     [14][15][16]
# 3     [17][18][19]
# 4         [20][21]

# %%
# The above numbering at the first coloumn is the index of the dataframe, which is automatically added.

# %%
df = tables[0][["Event", "Time"]] # df can be any variable, in this case, it is short for dataframe.

# %%
df.head()
# Out:
#             Event     Time
# 0   50m freestyle    20.91
# 1  100m freestyle    46.40
# 2  200m freestyle  1:42.00
# 3  400m freestyle  3:40.07
# 4  800m freestyle  7:32.12

# %%
df.to_dict() # The .to_dict() function is used to convert the dataframe into a dictionary.
# Out:
# {'Event': {0: '50m freestyle',
#   1: '100m freestyle',
#   2: '200m freestyle',
#   3: '400m freestyle',
#   4: '800m freestyle',
#   5: '1500m freestyle',
#   6: '50m backstroke',
#   7: '100m backstroke',
#   8: '200m backstroke',
#   9: '50m breaststroke',
#   10: '100m breaststroke',
#   11: '200m breaststroke',
#   12: '50m butterfly',
#   13: '100m butterfly',
#   14: '200m butterfly',
#   15: '200m individual medley',
#   16: '400m individual medley',
#   17: '4 × 100 m freestyle relay',
#   18: '4 × 200 m freestyle relay',
#   19: '4 × 100 m medley relay'},
#  'Time': {0: '20.91',
#   1: '46.40',
#   2: '1:42.00',
#   3: '3:40.07',
#   4: '7:32.12',
#   5: '14:30.67',
#   6: '23.55',
#   7: '51.60',
#   8: '1:51.92',
#   9: '25.95',
#   10: '56.88',
#   11: '2:05.48',
#   12: '22.27',
#   13: '49.45',
#   14: '1:50.34',
#   15: '1:54.00',
#   16: '4:02.50',
#   17: '3:08.24',
#   18: '6:58.55',
#   19: '3:26.78'}}

# %%
df.tail() # The .tail() function is used to display the last 5 rows of the dataframe, by default.
# Out:
#                         Event     Time
# 15     200m individual medley  1:54.00
# 16     400m individual medley  4:02.50
# 17  4 × 100 m freestyle relay  3:08.24
# 18  4 × 200 m freestyle relay  6:58.55
# 19     4 × 100 m medley relay  3:26.78

# %%
df[df["Event"].str.contains("relay")] # The .str.contains() function is used to filter the dataframe based on a specific string.
# Out:
#                         Event     Time
# 17  4 × 100 m freestyle relay  3:08.24
# 18  4 × 200 m freestyle relay  6:58.55
# 19     4 × 100 m medley relay  3:26.78

# %%
df[~df["Event"].str.contains("relay")] # '~' means NOT in Pandas.
# Out:
#                      Event      Time
# 0            50m freestyle     20.91
# 1           100m freestyle     46.40
# 2           200m freestyle   1:42.00
# 3           400m freestyle   3:40.07
# 4           800m freestyle   7:32.12
# 5          1500m freestyle  14:30.67
# 6           50m backstroke     23.55
# 7          100m backstroke     51.60
# 8          200m backstroke   1:51.92
# 9         50m breaststroke     25.95
# 10       100m breaststroke     56.88
# 11       200m breaststroke   2:05.48
# 12           50m butterfly     22.27
# 13          100m butterfly     49.45
# 14          200m butterfly   1:50.34
# 15  200m individual medley   1:54.00
# 16  400m individual medley   4:02.50

# %%
df = df[~df["Event"].str.contains("relay")] # assign the selection to a variable.

# %%
df.to_dict("records") # Close to what we want, but not quite.
# Out:
# [{'Event': '50m freestyle', 'Time': '20.91'},
#  {'Event': '100m freestyle', 'Time': '46.40'},
#  {'Event': '200m freestyle', 'Time': '1:42.00'},
#  {'Event': '400m freestyle', 'Time': '3:40.07'},
#  {'Event': '800m freestyle', 'Time': '7:32.12'},
#  {'Event': '1500m freestyle', 'Time': '14:30.67'},
#  {'Event': '50m backstroke', 'Time': '23.55'},
#  {'Event': '100m backstroke', 'Time': '51.60'},
#  {'Event': '200m backstroke', 'Time': '1:51.92'},
#  {'Event': '50m breaststroke', 'Time': '25.95'},
#  {'Event': '100m breaststroke', 'Time': '56.88'},
#  {'Event': '200m breaststroke', 'Time': '2:05.48'},
#  {'Event': '50m butterfly', 'Time': '22.27'},
#  {'Event': '100m butterfly', 'Time': '49.45'},
#  {'Event': '200m butterfly', 'Time': '1:50.34'},
#  {'Event': '200m individual medley', 'Time': '1:54.00'},
#  {'Event': '400m individual medley', 'Time': '4:02.50'}]

# %%
# Time to flex.

# %%
df = df.set_index("Event") # so, index is the sub-key, not the main key.
df.head()
# Out:
#                    Time
# Event
# 50m freestyle     20.91
# 100m freestyle    46.40
# 200m freestyle  1:42.00
# 400m freestyle  3:40.07
# 800m freestyle  7:32.12

# %%
df.to_dict() # again, just returning the result.
# Out:
# {'Time': {'50m freestyle': '20.91',
#   '100m freestyle': '46.40',
#   '200m freestyle': '1:42.00',
#   '400m freestyle': '3:40.07',
#   '800m freestyle': '7:32.12',
#   '1500m freestyle': '14:30.67',
#   '50m backstroke': '23.55',
#   '100m backstroke': '51.60',
#   '200m backstroke': '1:51.92',
#   '50m breaststroke': '25.95',
#   '100m breaststroke': '56.88',
#   '200m breaststroke': '2:05.48',
#   '50m butterfly': '22.27',
#   '100m butterfly': '49.45',
#   '200m butterfly': '1:50.34',
#   '200m individual medley': '1:54.00',
#   '400m individual medley': '4:02.50'}}

# %%
records = {} 
records["LC Men"] = df.to_dict()["Time"] # Change the main key. Using new main key = old main key.

# %%
records
# Out:
# {'LC Men': {'50m freestyle': '20.91',
#   '100m freestyle': '46.40',
#   '200m freestyle': '1:42.00',
#   '400m freestyle': '3:40.07',
#   '800m freestyle': '7:32.12',
#   '1500m freestyle': '14:30.67',
#   '50m backstroke': '23.55',
#   '100m backstroke': '51.60',
#   '200m backstroke': '1:51.92',
#   '50m breaststroke': '25.95',
#   '100m breaststroke': '56.88',
#   '200m breaststroke': '2:05.48',
#   '50m butterfly': '22.27',
#   '100m butterfly': '49.45',
#   '200m butterfly': '1:50.34',
#   '200m individual medley': '1:54.00',
#   '400m individual medley': '4:02.50'}}

# %%
RECORDS = (0, 2, 4, 5)
COURSES = ("LC Men", "LC Women", "SC Men", "SC Women")

records = {}
for table, course in zip(RECORDS, COURSES):
    df = tables[table][["Event", "Time"]]
    df = df[~df["Event"].str.contains("relay")]
    df = df.set_index("Event")
    records[course] = df.to_dict()["Time"]

# %%
import json

with open("records.json") as jf:
    gazpacho_records = json.load(jf)

# %%
records == gazpacho_records
# Out:
# True

# %%
records["SC Women"]["100m butterfly"]
# Out:
# '52.71'

# %%
gazpacho_records["SC Women"]["100m butterfly"]
# Out:
# '52.71'
